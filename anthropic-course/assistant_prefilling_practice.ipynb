# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=None, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    if temperature:
        params["temperature"] = temperature

    message = client.messages.create(**params)
    return message.content[0].text

# %%
def run_prompt():
    messages = []
    add_user_message(messages, "Hello, can you please tell me how a pdf works in markdown format?")
    add_assistant_message(messages, "```md # Initialization\n\n```")
    output = chat(messages)
    return output

message = run_prompt()

# %%
from IPython.display import Markdown


Markdown(message)
# Out:
# python
# from reportlab.lib.pagesizes import letter
# from reportlab.pdfgen import canvas
#
# # Create PDF
# c = canvas.Canvas("example.pdf", pagesize=letter)
# c.drawString(100, 750, "Hello, PDF!")
# c.save()
# ```
#
# ## Basic Structure
#
# A PDF (Portable Document Format) is a file format designed to present documents consistently across different devices and platforms. Here's how it works:
#
# ### Key Components
#
# 1. **File Header**
#    - Starts with `%PDF-1.X` (version number)
#    - Identifies the file as a PDF
#
# 2. **Body**
#    - Contains objects that make up the document
#    - Text, images, fonts, pages, etc.
#    - Each object has a unique identifier number
#
# 3. **Cross-Reference Table (xref)**
#    - Maps all objects in the document
#    - Contains byte offsets for each object
#    - Allows quick access to any object
#
# 4. **Trailer**
#    - References the root object and xref table
#    - Points to the catalog, info, and root page
#
# ### How Rendering Works
#
# ...
