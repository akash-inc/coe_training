# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 3000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write one to explain the difference between a semantic index and a BM25 index.")

chat(messages, thinking=True)
# Out:
# Message(id='msg_01EM6L6NCZ6Y2cFuZxhc6CYR', container=None, content=[ThinkingBlock(signature='...', thinking="This is a straightforward technical question asking me to explain the difference between semantic indexing and BM25 indexing. Let me break down both approaches clearly.\n\n**BM25 (Best Matching 25):**\n- Lexical/keyword-based retrieval method\n- Ranks documents based on term frequency and inverse document frequency\n- Looks for exact word matches\n- Fast and efficient\n- Doesn't understand meaning or context\n\n**Semantic Index:**\n- Uses embeddings/vectors to represent meaning\n- Understands context and semantics\n- Can match conceptually similar content even without exact keywords\n- Typically uses neural networks/transformers\n- More computationally expensive\n\nLet me write a clear, concise explanation.", type='thinking'), TextBlock(citations=None, text='# Semantic Index vs BM25 Index\n\n## **BM25 Index** (Lexical/Keyword-Based)\n\n**How it works:** Ranks documents based on exact word matches using statistical frequency analysis.\n\n- Looks for **exact keyword matches** between query and documents\n- Scores based on term frequency (TF) and inverse document frequency (IDF)\n- Fast and computationally cheap\n- No understanding of meaning or context\n\n**Example:**\n- Query: "laptop computer"\n- Finds documents containing the exact words "laptop" and/or "computer"\n- Misses: "portable PC" or "notebook device" (different words, same meaning)\n\n## **Semantic Index** (Meaning-Based)\n\n**How it works:** Converts text into vector embeddings that capture meaning, then finds conceptually similar content.\n\n- Understands **context and meaning**, not just keywords\n- Uses neural networks (like transformers) to create embeddings\n- Matches concepts even with different words\n- Slower and more resource-intensive\n\n**Example:**\n- Query: "laptop computer"\n- Also finds: "portable PC," "notebook device," "MacBook" (similar meaning)\n- Understands synonyms, related concepts, and context\n\n## **Key Difference**\n\n**BM25**: "Do these documents contain these *words*?"\n\n**Semantic**: "Do these documents mean the *same thing*?"\n\n## **When to Use Each**\n\n- **BM25**: Known terminology, exact matches needed, speed critical\n- **Semantic**: Natural language queries, concept matching, user doesn\'t know exact terms\n- **Hybrid**: Combine both for best results!', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=54, output_tokens=543, server_tool_use=None, service_tier='standard'))
