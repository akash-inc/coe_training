# %% [markdown]
# # Install dependencies

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./.venv/lib/python3.9/site-packages (0.97.0)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.9/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.9/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./.venv/lib/python3.9/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.9/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.9/site-packages (from anthropic) (2.13.3)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.9/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./.venv/lib/python3.9/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in ./.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #Load env variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Create an API client

# %%
import os

from anthropic import Anthropic

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))
model = "claude-sonnet-4-6"

# %% [markdown]
# # Helper functions

# %%
def add_user_message(messages, user_message):
    messages.append({
        "role": "user",
        "content": user_message
    })

def add_assistant_message(messages, assistant_message):
    messages.append({
        "role": "assistant",
        "content": assistant_message
    })

def chat(messages, system):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    if system:
        params["system"] = system
    try:
        message = client.messages.create(
            **params
        )
        return message.content[0].text
    


    except Exception as e:
        print("An error occurred:")
        print(type(e).__name__)
        return e

# %% [markdown]
# # Make a request

# %%
messages = []
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
add_user_message(messages, "How do I solve 2x + 3 = 11 for x?")
answer = chat(messages, system)

# %%
answer
# Out:
# "Let's work through this together step by step!\n\nThe goal is to **get x by itself** on one side of the equation.\n\nLet's start with what you see:\n**2x + 3 = 11**\n\n**First step:** There's a 3 being added on the left side. What could you do to *both sides* of the equation to start removing that 3?"
